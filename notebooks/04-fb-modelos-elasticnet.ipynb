# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)

from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# # Primeiro momento faremos um pré processamento somente com as colunas categoricas

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
   ], 
   )

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %% [markdown]
# # Iniciando com um modelo básico

# %%
 target_transformer = PowerTransformer()

regressors = {
 "DummyRegressor": {
    "preprocessor": None,
    "regressor": DummyRegressor(strategy="mean"),
    "target_transformer": None,
 },
  "LinearRegression": {
    "preprocessor": preprocessamento,
    "regressor": LinearRegression(),
    "target_transformer": None,
 },
  "LinearRegression_target": {
    "preprocessor": preprocessamento,
    "regressor": LinearRegression(),
    "target_transformer": target_transformer,
 },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.005477      0.003 -0.000081
# 1            DummyRegressor  0.002995   0.003002 -0.000146
# 2            DummyRegressor  0.003001   0.004135 -0.001737
# 3            DummyRegressor  0.003212   0.005169 -0.000101
# 4            DummyRegressor     0.003   0.002997 -0.000114
# 5          LinearRegression  0.080025   0.012019  0.682162
# 6          LinearRegression  0.026039   0.009191   0.66999
# 7          LinearRegression  0.030177   0.011001  0.649247
# 8          LinearRegression  0.029973   0.008823  0.669873
# 9          LinearRegression  0.023169   0.011792  0.669023
# 10  LinearRegression_target  0.050134   0.012751  0.684232
# 11  LinearRegression_target  0.039435   0.011399  0.671042
# 12  LinearRegression_target   0.04284      0.009  0.646094
# 13  LinearRegression_target  0.048486   0.010001  0.677544
# 14  LinearRegression_target  0.048637   0.010115  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.008477
# 1                 -75787.787194                    -95217.629397     0.005997
# 2                 -76753.598961                    -96253.253947     0.007136
# 3                 -76837.804811                    -95983.885799     0.008381
# 4                 -76617.245449                    -96182.764729     0.005996
# 5                 -39855.690996                    -54254.958188     0.092044
# 6                 -40272.565467                    -54695.230283      0.03523
# 7                  -42178.05929                    -56955.988706     0.041178
# 8                 -40806.492497                    -55146.318803     0.038796
# 9                 -40788.496497                     -55331.35106     0.034961
# 10                -38127.990135                    -54078.018211     0.062885
# 11                -38515.387238                    -54607.941484     0.050834
# 12                -40531.127445                    -57211.351393      0.05184
# 13                -38827.013003                     -54501.88036     0.058487
# 14                -38544.774208                    -54659.330465     0.058752

# %% [markdown]
# # Avaliamos pela media que o r2 melhorou levemente comparado com o target. 0 MAE e o RMSE também melhorou levemente.

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.003537    0.00366 -0.000436
# LinearRegression         0.037877   0.010565  0.668059
# LinearRegression_target  0.045906   0.010653  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38909.258406
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.007197
# LinearRegression                           -55276.769408     0.048442
# LinearRegression_target                    -55011.704383      0.05656

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0],
    "regressor__reg__l1_ratio": [0.1, 0.25, 0.5, 0.75, 0.9],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=ElasticNet(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.397e+02, tolerance: 1.785e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.1}

# %%
grid_search.best_score_
# Out:
# np.float64(-51319.51050431832)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.602420
# robust_scaler_poly__longitude                         -0.381515
# robust_scaler_poly__population_per_household          -0.343052
# robust_scaler_poly__latitude                          -0.212569
# robust_scaler_poly__latitude^2                        -0.194991
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.092670
# robust_scaler_poly__housing_median_age longitude^2     0.108309
# robust_scaler_poly__bedrooms_per_room                  0.129502
# robust_scaler_poly__housing_median_age median_i...     0.181128
# robust_scaler_poly__median_income                      0.720593
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household ro...         -0.0
# robust_scaler_poly__total_rooms^3                           0.0
# ...                                                         ...
# robust_scaler_poly__longitude population^2                 -0.0
# robust_scaler_poly__population rooms_per_househ...         -0.0
# robust_scaler_poly__population rooms_per_househ...         -0.0
# robust_scaler_poly__population total_bedrooms^2            -0.0
# robust_scaler_poly__population total_bedrooms t...          0.0
#
# [208 rows x 1 columns]

# %%
coefs[coefs["coeficiente"].between(-100_00, 100_000)]
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.602420
# robust_scaler_poly__longitude                         -0.381515
# robust_scaler_poly__population_per_household          -0.343052
# robust_scaler_poly__latitude                          -0.212569
# robust_scaler_poly__latitude^2                        -0.194991
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.092670
# robust_scaler_poly__housing_median_age longitude^2     0.108309
# robust_scaler_poly__bedrooms_per_room                  0.129502
# robust_scaler_poly__housing_median_age median_i...     0.181128
# robust_scaler_poly__median_income                      0.720593
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-100_000, 100_000)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plot_coeficientes(coefs[~coefs["coeficiente"].between(-100_000, 100_000)])
#
# File c:\Users\carol\OneDrive\Desktop\PROJETOS\Projeto_Regressao\notebooks\src\graficos.py:16, in plot_coeficientes(df_coefs, tituto)
#      15 def plot_coeficientes(df_coefs, tituto="Coeficientes"):
# ---> 16     df_coefs.plot.barh()
#      17     plt.title(tituto)
#      18     plt.axvline(x=0, color=".5")
#
# File c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\pandas\plotting\_core.py:1280, in PlotAccessor.barh(self, x, y, **kwargs)
#    1194 @Appender(
#    1195     """
#    1196     See Also
#    (...)
#    1269     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1270 ) -> PlotAccessor:
#    1271     """
#    1272     Make a horizontal bar plot.
#    1273
#    (...)
#    1278     other axis represents a measured value.
#    1279     """
# -> 1280     return self(kind="barh", x=x, y=y, **kwargs)
#
# File c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\pandas\plotting\_matplotlib\core.py:508, in MPLPlot.generate(self)
#     506 for ax in self.axes:
#     507     self._post_plot_logic_common(ax)
# --> 508     self._post_plot_logic(ax, self.data)
#
# File c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1966, in BarPlot._post_plot_logic(self, ax, data)
#    1963 else:
#    1964     str_index = [pprint_thing(key) for key in range(data.shape[0])]
# -> 1966 s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1967 e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1969 self._decorate_ticks(ax, self._get_index_name(), str_index, s_edge, e_edge)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
     },
        "LinearRegression_target": {
            "preprocessor": preprocessamento,
            "regressor": LinearRegression(),
            "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.045e+01, tolerance: 1.430e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.258e+01, tolerance: 1.421e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+01, tolerance: 1.437e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.917e+02, tolerance: 1.416e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\carol\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.933e+01, tolerance: 1.434e+00
#   model = cd_fast.enet_coordinate_descent(
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor  0.002051   0.003212 -0.000081
# 1                 DummyRegressor  0.003098   0.003115 -0.000146
# 2                 DummyRegressor  0.002542   0.003043 -0.001737
# 3                 DummyRegressor  0.000999   0.003001 -0.000101
# 4                 DummyRegressor   0.00346    0.00302 -0.000114
# 5               LinearRegression  1.453515    0.00914  0.682162
# 6               LinearRegression  0.025761   0.010444   0.66999
# 7               LinearRegression  0.022256   0.008254  0.649247
# 8               LinearRegression   0.02365   0.009629  0.669873
# 9               LinearRegression    0.0237    0.00723  0.669023
# 10       LinearRegression_target  0.027243   0.008572  0.692361
# 11       LinearRegression_target  0.029159   0.008702  0.678709
# 12       LinearRegression_target  0.030867   0.009901  0.654217
# 13       LinearRegression_target  0.029716   0.009718  0.684058
# 14       LinearRegression_target  0.029583   0.009256   0.68256
# 15  LinearRegression_grid_search  3.669256   0.026765  0.734361
# 16  LinearRegression_grid_search  4.158998   0.023673  0.713701
# 17  LinearRegression_grid_search  3.969473   0.023313  0.687797
# 18  LinearRegression_grid_search  4.204845   0.024709   0.71821
# 19  LinearRegression_grid_search   3.76431    0.02828  0.715809
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.005263
# 1                 -75787.787194                    -95217.629397     0.006213
# 2                 -76753.598961                    -96253.253947     0.005585
# 3                 -76837.804811                    -95983.885799        0.004
# 4                 -76617.245449                    -96182.764729      0.00648
# 5                 -39855.690996                    -54254.958188     1.462656
# 6                 -40272.565467                    -54695.230283     0.036205
# 7                  -42178.05929                    -56955.988706      0.03051
# 8                 -40806.492497                    -55146.318803     0.033279
# 9                 -40788.496497                     -55331.35106      0.03093
# 10                -37797.874665                    -53377.359198     0.035815
# 11                -38276.391491                    -53967.869244     0.037861
# 12                -40286.547692                    -56550.991275     0.040768
# 13                -38597.989102                    -53948.607631     0.039434
# 14                 -38433.52726                    -54187.987303     0.038839
# 15                -34872.309402                    -49600.074357     3.696022
# 16                -35650.549718                    -50944.285418     4.182671
# 17                -37610.685871                    -53734.972748     3.992785
# 18                -35935.902189                    -50949.446659     4.229554
# 19                -35968.470854                    -51271.672559      3.79259

# %%
df_resultados.groupby("model").mean()
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                 0.00243   0.003078 -0.000436
# LinearRegression              0.309776   0.008939  0.668059
# LinearRegression_grid_search  3.953376   0.025348  0.713976
# LinearRegression_target       0.029314    0.00923  0.678381
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_grid_search                -36007.583607
# LinearRegression_target                     -38678.466042
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.005508
# LinearRegression                                -55276.769408     0.318716
# LinearRegression_grid_search                    -51300.090348     3.978724
# LinearRegression_target                          -54406.56293     0.038543

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                 0.00243   0.003078 -0.000436
# LinearRegression              0.309776   0.008939  0.668059
# LinearRegression_target       0.029314    0.00923  0.678381
# LinearRegression_grid_search  3.953376   0.025348  0.713976
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_target                     -38678.466042
# LinearRegression_grid_search                -36007.583607
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.005508
# LinearRegression                                -55276.769408     0.318716
# LinearRegression_target                          -54406.56293     0.038543
# LinearRegression_grid_search                    -51300.090348     3.978724

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
