# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)

from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# # Primeiro momento faremos um pré processamento somente com as colunas categoricas

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
   ], 
   )

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %% [markdown]
# # Iniciando com um modelo básico

# %%
 target_transformer = PowerTransformer()

regressors = {
 "DummyRegressor": {
    "preprocessor": None,
    "regressor": DummyRegressor(strategy="mean"),
    "target_transformer": None,
 },
  "LinearRegression": {
    "preprocessor": preprocessamento,
    "regressor": LinearRegression(),
    "target_transformer": None,
 },
  "LinearRegression_target": {
    "preprocessor": preprocessamento,
    "regressor": LinearRegression(),
    "target_transformer": target_transformer,
 },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.006327   0.008698 -0.000081
# 1            DummyRegressor  0.006018   0.008747 -0.000146
# 2            DummyRegressor  0.005009   0.007888 -0.001737
# 3            DummyRegressor  0.003222   0.008308 -0.000101
# 4            DummyRegressor  0.004734   0.006005 -0.000114
# 5          LinearRegression   0.04397   0.015605  0.682162
# 6          LinearRegression  0.044144   0.015093   0.66999
# 7          LinearRegression  0.039889   0.016349  0.649247
# 8          LinearRegression  0.044061   0.015034  0.669873
# 9          LinearRegression  0.044238     0.0161  0.669023
# 10  LinearRegression_target  0.071058   0.016563  0.684232
# 11  LinearRegression_target  0.064529    0.01552  0.671042
# 12  LinearRegression_target  0.062412   0.016597  0.646094
# 13  LinearRegression_target  0.070159    0.01606  0.677544
# 14  LinearRegression_target  0.067204   0.019319  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.015025
# 1                 -75787.787194                    -95217.629397     0.014766
# 2                 -76753.598961                    -96253.253947     0.012897
# 3                 -76837.804811                    -95983.885799      0.01153
# 4                 -76617.245449                    -96182.764729     0.010738
# 5                 -39855.690996                    -54254.958188     0.059575
# 6                 -40272.565467                    -54695.230283     0.059237
# 7                  -42178.05929                    -56955.988706     0.056238
# 8                 -40806.492497                    -55146.318803     0.059096
# 9                 -40788.496497                     -55331.35106     0.060338
# 10                -38127.990135                    -54078.018211     0.087621
# 11                -38515.387238                    -54607.941484     0.080049
# 12                -40531.127445                    -57211.351393     0.079009
# 13                -38827.013003                     -54501.88036     0.086219
# 14                -38544.774208                    -54659.330465     0.086524

# %% [markdown]
# # Avaliamos pela media que o r2 melhorou levemente comparado com o target. 0 MAE e o RMSE também melhorou levemente.

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.005062   0.007929 -0.000436
# LinearRegression         0.043261   0.015636  0.668059
# LinearRegression_target  0.067072   0.016812  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38909.258406
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.012991
# LinearRegression                           -55276.769408     0.058897
# LinearRegression_target                    -55011.704383     0.083884

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree":[1, 2, 3],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3}

# %%
grid_search.best_score_
# Out:
# np.float64(-51135.92281364791)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                       coeficiente
# robust_scaler_poly__longitude total_rooms          -319894.828914
# robust_scaler_poly__housing_median_age total_rooms -229869.299894
# robust_scaler_poly__latitude total_rooms           -223771.460087
# robust_scaler_poly__rooms_per_household total_b... -216002.853021
# robust_scaler_poly__latitude population_per_hou... -210128.552627
# ...                                                           ...
# robust_scaler_poly__households                      168418.962852
# robust_scaler_poly__longitude population            174256.115433
# robust_scaler_poly__latitude population rooms_p...  211493.341249
# robust_scaler_poly__bedrooms_per_room households    222589.594180
# robust_scaler_poly__latitude population             235307.700467
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs["coeficiente"].between(-100_00, 100_000)]
# Out:
#                                                      coeficiente
# robust_scaler_poly__households rooms_per_househ...  -9672.508346
# robust_scaler_poly__bedrooms_per_room populatio...  -8488.865667
# robust_scaler_poly__bedrooms_per_room latitude      -6969.885435
# robust_scaler_poly__households population           -6324.795430
# robust_scaler_poly__total_bedrooms total_rooms      -6168.859968
# ...                                                          ...
# robust_scaler_poly__housing_median_age total_be...  70377.301848
# robust_scaler_poly__bedrooms_per_room rooms_per...  75817.448046
# robust_scaler_poly__latitude rooms_per_household    80832.257565
# robust_scaler_poly__rooms_per_household^2           81435.020923
# robust_scaler_poly__households rooms_per_household  88427.072362
#
# [308 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-100_000, 100_000)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
     },
        "LinearRegression_target": {
            "preprocessor": preprocessamento,
            "regressor": LinearRegression(),
            "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "LinearRegression_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}

resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                            model  fit_time score_time   test_r2  \
# 0                 DummyRegressor  0.006086   0.005648 -0.000081
# 1                 DummyRegressor  0.005993   0.005003 -0.000146
# 2                 DummyRegressor  0.005594   0.006004 -0.001737
# 3                 DummyRegressor  0.004002   0.002995 -0.000101
# 4                 DummyRegressor  0.003522   0.004996 -0.000114
# 5               LinearRegression  0.038408      0.014  0.682162
# 6               LinearRegression  0.038387   0.014027   0.66999
# 7               LinearRegression  0.039582   0.015133  0.649247
# 8               LinearRegression  0.039252   0.015508  0.669873
# 9               LinearRegression  0.039996   0.015156  0.669023
# 10       LinearRegression_target   0.04983   0.017006  0.692209
# 11       LinearRegression_target  0.052256   0.016967  0.678383
# 12       LinearRegression_target  0.052343   0.013316  0.653377
# 13       LinearRegression_target  0.056125   0.014999  0.683631
# 14       LinearRegression_target  0.053729   0.018012  0.682549
# 15  LinearRegression_grid_search  0.311557   0.032876  0.728271
# 16  LinearRegression_grid_search  0.346242   0.031866  0.719329
# 17  LinearRegression_grid_search  0.349936   0.029746  0.690797
# 18  LinearRegression_grid_search  0.308515   0.029353  0.724137
# 19  LinearRegression_grid_search  0.305904   0.028474  0.717716
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.011734
# 1                 -75787.787194                    -95217.629397     0.010996
# 2                 -76753.598961                    -96253.253947     0.011598
# 3                 -76837.804811                    -95983.885799     0.006997
# 4                 -76617.245449                    -96182.764729     0.008518
# 5                 -39855.690996                    -54254.958188     0.052408
# 6                 -40272.565467                    -54695.230283     0.052413
# 7                  -42178.05929                    -56955.988706     0.054716
# 8                 -40806.492497                    -55146.318803      0.05476
# 9                 -40788.496497                     -55331.35106     0.055152
# 10                -37797.997391                    -53390.617983     0.066836
# 11                -38290.910988                    -53995.206814     0.069223
# 12                -40306.060538                     -56619.61116     0.065659
# 13                -38603.955889                    -53985.048856     0.071124
# 14                -38414.254111                    -54188.978566      0.07174
# 15                -34659.579952                    -50165.474922     0.344433
# 16                -35022.635519                    -50441.113312     0.378108
# 17                -37391.449877                    -53476.209219     0.379682
# 18                -35200.600604                    -50410.768205     0.337869
# 19                -35585.583822                    -51099.375674     0.334377

# %%
df_resultados.groupby("model").mean()
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.005039   0.004929 -0.000436
# LinearRegression              0.039125   0.014765  0.668059
# LinearRegression_grid_search  0.324431   0.030463   0.71605
# LinearRegression_target       0.052857    0.01606   0.67803
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_grid_search                -35571.969955
# LinearRegression_target                     -38682.635784
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.009969
# LinearRegression                                -55276.769408      0.05389
# LinearRegression_grid_search                    -51118.588266     0.354894
# LinearRegression_target                         -54435.892676     0.068916

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                               fit_time score_time   test_r2  \
# model
# DummyRegressor                0.005039   0.004929 -0.000436
# LinearRegression              0.039125   0.014765  0.668059
# LinearRegression_target       0.052857    0.01606   0.67803
# LinearRegression_grid_search  0.324431   0.030463   0.71605
#
#                              test_neg_mean_absolute_error  \
# model
# DummyRegressor                              -76702.495836
# LinearRegression                             -40780.26095
# LinearRegression_target                     -38682.635784
# LinearRegression_grid_search                -35571.969955
#
#                              test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                  -95975.447913     0.009969
# LinearRegression                                -55276.769408      0.05389
# LinearRegression_target                         -54435.892676     0.068916
# LinearRegression_grid_search                    -51118.588266     0.354894

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
